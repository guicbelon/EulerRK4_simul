# %% [markdown]
# ### Exercício Computacional - PMR3401
# #### Parte 1 - Método de Runge Kutta

# %%
# Importando o módulo da biblioteca
from meccomp_lib.ex_1 import *

# %% [markdown]
# #### Análise para Euler

# %%
# Definindo o sistema de passo igual a 0.01
system = System(step=0.01) 
euler_01 = Euler(system=system, simulation_time=60)

euler_01.simul()
euler_01.plot_results()

# %%
# Definindo o sistema de passo igual a 0.005
system = System(step=0.005) 
euler_005 = Euler(system=system, simulation_time=60)

euler_005.simul()
euler_005.plot_results()

# %%
# Definindo o sistema de passo igual a 0.002
system = System(step=0.002) 
euler_002 = Euler(system=system, simulation_time=60)

euler_002.simul()
euler_002.plot_results()

# %%
# Definindo o sistema de passo igual a 0.001
system = System(step=0.001) 
euler_001 = Euler(system=system, simulation_time=60)

euler_001.simul()
euler_001.plot_results()

# %%
# Definindo o sistema de passo igual a 0.0001
system = System(step=0.0001) 
euler_0001 = Euler(system=system, simulation_time=60)

euler_0001.simul()
euler_0001.plot_results()

# %%
# Definindo o sistema de passo igual a 0.0001 e velocidade igual a 2x
system = System(step=0.0001, theta_1_dot_initial=0.1, theta_2_dot_initial=0.2) 
euler_0001_v2 = Euler(system=system, simulation_time=60)

euler_0001_v2.simul()
euler_0001_v2.plot_results()

# %%
# Definindo o sistema de passo igual a 0.0001 e velocidade igual a 10x
system = System(step=0.0001, theta_1_dot_initial=0.5, theta_2_dot_initial=1.0) 
euler_0001_v10 = Euler(system=system, simulation_time=60)

euler_0001_v10.simul()
euler_0001_v10.plot_results()

# %% [markdown]
# #### Análise para Método de Runge Kutta de 4º Ordem

# %%
# Definindo o sistema de passo igual a 0.01
system = System(step=0.01) 
rk4_01 = RK4(system=system, simulation_time=60)

rk4_01.simul()
rk4_01.plot_results()

# %%
# Definindo o sistema de passo igual a 0.005
system = System(step=0.005) 
rk4_005 = RK4(system=system, simulation_time=60)

rk4_005.simul()
rk4_005.plot_results()

# %%
# Definindo o sistema de passo igual a 0.001
system = System(step=0.001) 
rk4_001 = RK4(system=system, simulation_time=60)

rk4_001.simul()
rk4_001.plot_results()

# %%
# Definindo o sistema de passo igual a 0.002
system = System(step=0.002) 
rk4_002 = RK4(system=system, simulation_time=60)

rk4_002.simul()
rk4_002.plot_results()

# %%
# Definindo o sistema de passo igual a 0.001
system = System(step=0.001) 
rk4_001 = RK4(system=system, simulation_time=60)

rk4_001.simul()
rk4_001.plot_results()

# %%
# Definindo o sistema de passo igual a 0.0001
system = System(step=0.0001) 
rk4_0001 = RK4(system=system, simulation_time=60)

rk4_0001.simul()
rk4_0001.plot_results()

# %%
# Definindo o sistema de passo igual a 0.0001 e velocidade igual a 2x
system = System(step=0.0001, theta_1_dot_initial=0.1, theta_2_dot_initial=0.2) 
rk4_0001_v2 = RK4(system=system, simulation_time=60)

rk4_0001_v2.simul()
rk4_0001_v2.plot_results()

# %%
# Definindo o sistema de passo igual a 0.0001 e velocidade igual a 10x
system = System(step=0.0001, theta_1_dot_initial=0.5, theta_2_dot_initial=1.0) 
rk4_0001_v10 = RK4(system=system, simulation_time=60)

rk4_0001_v10.simul()
rk4_0001_v10.plot_results()
