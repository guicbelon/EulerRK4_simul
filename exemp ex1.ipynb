# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from meccomp_lib import *

system = System(step=0.01) # Voce altera aqui as condições iniciais do sistema   
eule = Euler(system=system, simulation_time=60)

eule.simul()
eule.plot_results()

# %%
from meccomp_lib import *

system = System(step=0.005) # Voce altera aqui as condições iniciais do sistema   
eule = Euler(system=system, simulation_time=60)

eule.simul()
eule.plot_results()

# %%
from meccomp_lib import *

system = System(step=0.001) # Voce altera aqui as condições iniciais do sistema   
eule = Euler(system=system, simulation_time=60)

eule.simul()
eule.plot_results()

# %%
from meccomp_lib import *

system = System(step=0.0001) # Voce altera aqui as condições iniciais do sistema   
eule = Euler(system=system, simulation_time=60)

eule.simul()
eule.plot_results()

# %%
system = System(step=0.01)    
rk = RK4(system=system, simulation_time=60)

rk.simul()
rk.plot_results()

# %%
system = System(step=0.005)    
rk = RK4(system=system, simulation_time=60)

rk.simul()
rk.plot_results()

# %%
system = System(step=0.001)    
rk = RK4(system=system, simulation_time=60)

rk.simul()
rk.plot_results()

# %%
system = System(step=0.0001)    
rk = RK4(system=system, simulation_time=60)

rk.simul()
rk.plot_results()
