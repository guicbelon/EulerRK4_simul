# %% [markdown]
# ### Exercício Computacional - PMR3401
# #### Parte 2 - Método de Diferenças Finitas (MDF)

# %%
# Importando o módulo da biblioteca
from meccomp_lib.ex_2 import *

# Definindo alguns parâmetros globais
DELTA = 0.02
ALLOW_PRINT = False

# %% [markdown]
# #### Análise para 15 graus

# %%
# Definindo a malha para 15 graus
mesh_15 = Mesh(delta=DELTA, 
               rotation_angle_in_degrees=15,
               allow_print=ALLOW_PRINT)

# Exibindo o formato da malha
mesh_15.plot_mesh()

# Simulando a malha:
mesh_15.simul()

# %% [markdown]
# ##### Apresentando as imagens geradas para a malha rotacionada 15 graus

# %%
# Linha de corrente
mesh_15.plot_streamline()

# Velocidades absolutas
mesh_15.plot_velocities()

# Pressão
mesh_15.plot_pressure(plot_contour=True)
mesh_15.plot_pressure(plot_contour=False)
mesh_15.plot_pressure(plot_contour=False, plot_minimum=True)

# %%
# Vetores de velocidades
mesh_15_vel = Mesh(rotation_angle_in_degrees=15,delta = 0.2, allow_print = False)
mesh_15_vel.simul()
mesh_15_vel.plot_velocities_vectors()

# %%
# Cálculo das forças de arrasto e sustentação
mesh_15.calculate_forces()

# Força de arrasto
print(f"Força de arrasto: {mesh_15.drag_forces} N/m")

# Força de sustentação
print(f"Força de sustentação: {mesh_15.lifting_forces} N/m")
# Out:
# Força de arrasto: -0.19412965716186878 N/m
# Força de sustentação: 4.69967016972621 N/m

# %%
# Cálculo das forças para velocidade de 10m/s
mesh_15_10 = Mesh(delta=0.05, 
                  rotation_angle_in_degrees=15,
                  U_infinity=10,
                  allow_print=ALLOW_PRINT)

# Novas simulações
mesh_15_10.simul()
mesh_15_10.calculate_forces()

# %%
# Força de arrasto
print(f"Nova força de arrasto para velocidade de 10m/s: {mesh_15_10.drag_forces} N/m")

# Força de sustentação
print(f"Nova força de sustentação para velocidade de 10m/s: {mesh_15_10.lifting_forces} N/m")
# Out:
# Nova força de arrasto para velocidade de 10m/s: -0.06336232794544146 N/m
# Nova força de sustentação para velocidade de 10m/s: 1.2111232649446728 N/m

# %%
# Cálculo das forças para velocidade de 90m/s
mesh_15_90 = Mesh(delta=0.05, 
                  rotation_angle_in_degrees=15,
                  U_infinity=90,
                  allow_print=ALLOW_PRINT)

# Novas simulações
mesh_15_90.simul()
mesh_15_90.calculate_forces()

# %%
# Força de arrasto
print(f"Nova força de arrasto para velocidade de 90m/s: {mesh_15_90.drag_forces} N/m")

# Força de sustentação
print(f"Nova força de sustentação para velocidade de 90m/s: {mesh_15_90.lifting_forces} N/m")
# Out:
# Nova força de arrasto para velocidade de 90m/s: -5.132348563248464 N/m
# Nova força de sustentação para velocidade de 90m/s: 98.10098446825728 N/m

# %% [markdown]
# #### Análise para 90 graus

# %%
# Definindo a malha para 15 graus
mesh_90 = Mesh(delta=DELTA, 
               rotation_angle_in_degrees=90,
               allow_print=ALLOW_PRINT)

# Exibindo o formato da malha
mesh_90.plot_mesh()

# Simulando a malha:
mesh_90.simul()

# %% [markdown]
# ##### Apresentando as imagens geradas para a malha rotacionada 90 graus

# %%
# Linha de corrente
mesh_90.plot_streamline()

# Velocidades absolutas
mesh_90.plot_velocities()

# Pressão
mesh_90.plot_pressure(plot_contour=True)
mesh_90.plot_pressure(plot_contour=False)
mesh_90.plot_pressure(plot_contour=False, plot_minimum=True)

# %%
# Vetores de velocidades
mesh_90_vel = Mesh(rotation_angle_in_degrees=90,delta = 0.1, allow_print = False)
mesh_90_vel.simul()
mesh_90_vel.plot_velocities_vectors()

# %%
# Cálculo das forças de arrasto e sustentação
mesh_90.calculate_forces()

# Força de arrasto
print(f"Força de arrasto: {mesh_90.drag_forces} N/m")

# Força de sustentação
print(f"Força de sustentação: {mesh_90.lifting_forces} N/m")
# Out:
# Força de arrasto: 6.2412373076605085 N/m
# Força de sustentação: 67.80203612038692 N/m

# %%
# Cálculo das forças para velocidade de 10m/s
mesh_90_10 = Mesh(delta=0.05, 
                  rotation_angle_in_degrees=90,
                  U_infinity=10,
                  allow_print=ALLOW_PRINT)

# Novas simulações
mesh_90_10.simul()
mesh_90_10.calculate_forces()

# %%
# Força de arrasto
print(f"Nova força de arrasto para velocidade de 10m/s: {mesh_90_10.drag_forces} N/m")

# Força de sustentação
print(f"Nova força de sustentação para velocidade de 10m/s: {mesh_90_10.lifting_forces} N/m")
# Out:
# Nova força de arrasto para velocidade de 10m/s: 0.2537981919023115 N/m
# Nova força de sustentação para velocidade de 10m/s: 12.290892693649221 N/m

# %%
# Cálculo das forças para velocidade de 90m/s
mesh_90_90 = Mesh(delta=0.05, 
                  rotation_angle_in_degrees=90,
                  U_infinity=90,
                  allow_print=ALLOW_PRINT)

# Novas simulações
mesh_90_90.simul()
mesh_90_90.calculate_forces()

# %%
# Força de arrasto
print(f"Nova força de arrasto para velocidade de 90m/s: {mesh_90_90.drag_forces} N/m")

# Força de sustentação
print(f"Nova força de sustentação para velocidade de 90m/s: {mesh_90_90.lifting_forces} N/m")
# Out:
# Nova força de arrasto para velocidade de 90m/s: 20.55765354383673 N/m
# Nova força de sustentação para velocidade de 90m/s: 995.562308183937 N/m
